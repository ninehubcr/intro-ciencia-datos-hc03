# %%
import pandas as pd
import matplotlib.pyplot as plt

asteroid_df = pd.read_json('https://github.com/Marcel-Jan/Fun-with-Python/blob/master/mpcorb_10kasteroids.json?raw=true')
plt.scatter(asteroid_df.a, asteroid_df.e, color='k', marker='.', s=1)
plt.xlim(2, 3.5)
plt.ylim(0, .8)
plt.xlabel('Semimajor axis (AU)')
plt.ylabel('Eccentricity')
plt.title('First 10K asteroids discovered')
plt.show()

# %%
asteroid_df.head()
# Out:
#   Perturbers  Synodic_period  Num_opps  Aphelion_dist    Last_obs       Peri  \
# 0        M-v        1.277490       113       2.976646  2017-03-05   73.02368
# 1        M-v        1.276403       108       3.412551  2017-06-01  309.99154
# 2        M-v        1.297689       104       3.353953  2017-05-21  248.20648
# 3        M-p        1.380286       100       2.572336  2017-03-23  150.94297
# 4        M-v        1.319701        75       3.065979  2017-06-02  358.75689
#
#    Orbital_period  Perihelion_dist         n         e  ...          M  \
# 0        4.603733         2.558173  0.214089  0.075607  ...  309.49412
# 1        4.617903         2.133619  0.213432  0.230597  ...  291.65136
# 2        4.359216         1.983110  0.226097  0.256853  ...  259.23491
# 3        3.629598         2.151219  0.271547  0.089152  ...  292.71034
# 4        4.127926         2.080591  0.238766  0.191465  ...  139.06218
#
#              Tp     H         i  Hex_flags  U NEO_flag  One_km_NEO_flag  \
# 0  2.458236e+06  3.34  10.59322       0000  0      NaN              NaN
# 1  2.458321e+06  4.13  34.83792       0000  0      NaN              NaN
# 2  2.458446e+06  5.33  12.98996       0000  0      NaN              NaN
# 3  2.458248e+06  3.20   7.14002       0000  0      NaN              NaN
# 4  2.457418e+06  6.85   5.36794       0000  0      NaN              NaN
#
#   PHA_flag Critical_list_numbered_object_flag
# 0      NaN                                NaN
# 1      NaN                                NaN
# 2      NaN                                NaN
# 3      NaN                                NaN
# 4      NaN                                NaN
#
# [5 rows x 36 columns]

# %%
asteroid_df.columns
# Out:
# Index(['Perturbers', 'Synodic_period', 'Num_opps', 'Aphelion_dist', 'Last_obs',
#        'Peri', 'Orbital_period', 'Perihelion_dist', 'n', 'e', 'a', 'Ref',
#        'Name', 'Semilatus_rectum', 'Num_obs', 'Orbit_type', 'Computer', 'rms',
#        'Number', 'Principal_desig', 'Node', 'Arc_years', 'Epoch',
#        'Perturbers_2', 'Other_desigs', 'G', 'M', 'Tp', 'H', 'i', 'Hex_flags',
#        'U', 'NEO_flag', 'One_km_NEO_flag', 'PHA_flag',
#        'Critical_list_numbered_object_flag'],
#       dtype='object')

# %%
asteroid_df['n'].unique()
# Out:
# array([ 0.12,  0.11,  0.32,  0.15,  0.24,  0.28,  0.17,  0.22,  0.23,
#         0.2 ,  0.25,  0.1 ,  0.21,  0.19,  0.33,  0.46,  0.07,  0.06,
#         0.16,  0.08,  0.18,  0.27,  0.48,  0.01,  0.05,  0.14,  0.4 ,
#         0.35,  0.04,  0.13, -0.04,  0.03,  0.29, -0.02,  0.09,  0.37,
#        -0.03, -0.06,  0.26,  0.34, -0.12,  0.3 ,  0.6 ])

# %%
for col in asteroid_df:
    print(col, asteroid_df[col].unique())

# %%
asteroid_df.corr()
# Out:
#                                     Synodic_period  Num_opps  Aphelion_dist  \
# Synodic_period                            1.000000 -0.008886      -0.058545
# Num_opps                                 -0.008886  1.000000       0.116740
# Aphelion_dist                            -0.058545  0.116740       1.000000
# Peri                                     -0.015290  0.018718       0.021656
# Orbital_period                           -0.048523  0.113551       0.952693
# Perihelion_dist                          -0.087796  0.219626       0.631592
# n                                         0.243070 -0.235744      -0.594912
# e                                         0.075664 -0.110735       0.197109
# a                                        -0.077461  0.174153       0.939460
# Semilatus_rectum                         -0.089216  0.211162       0.806866
# Num_obs                                  -0.045745  0.640660      -0.054715
# rms                                       0.051123 -0.044054       0.042962
# Node                                     -0.001689 -0.015983      -0.038163
# Epoch                                          NaN       NaN            NaN
# G                                         0.000260  0.137773      -0.011867
# M                                         0.009851  0.010760      -0.008826
# Tp                                        0.001276  0.007462      -0.141505
# H                                         0.065764 -0.829405      -0.346683
# i                                         0.029664 -0.002395       0.144103
# U                                         0.422038 -0.071393       0.017295
# NEO_flag                                       NaN       NaN            NaN
# One_km_NEO_flag                                NaN       NaN            NaN
# PHA_flag                                       NaN       NaN            NaN
# Critical_list_numbered_object_flag             NaN       NaN            NaN
#
#                                         Peri  Orbital_period  Perihelion_dist  \
# Synodic_period                     -0.015290       -0.048523        -0.087796
# Num_opps                            0.018718        0.113551         0.219626
# Aphelion_dist                       0.021656        0.952693         0.631592
# Peri                                1.000000        0.019708         0.012228
# Orbital_period                      0.019708        1.000000         0.725120
# Perihelion_dist                     0.012228        0.725120         1.000000
# n                                  -0.012193       -0.538186        -0.767580
# e                                   0.002003       -0.033342        -0.528807
# a                                   0.019704        0.949559         0.859020
# Semilatus_rectum                    0.017363        0.852162         0.958730
# Num_obs                             0.056640       -0.022807         0.103850
# rms                                -0.009344        0.013036        -0.079926
# Node                               -0.139234       -0.033861        -0.036276
# Epoch                                    NaN             NaN              NaN
# G                                   0.006092       -0.007970        -0.007303
# M                                  -0.010627       -0.007464         0.005567
# Tp                                 -0.012324       -0.173878        -0.018955
# H                                  -0.020842       -0.343485        -0.517354
# i                                  -0.007857        0.094086        -0.001724
# U                                  -0.014046        0.006758        -0.167753
# NEO_flag                                 NaN             NaN              NaN
# One_km_NEO_flag                          NaN             NaN              NaN
# PHA_flag                                 NaN             NaN              NaN
# Critical_list_numbered_object_flag       NaN             NaN              NaN
#
#                                            n         e         a  \
# Synodic_period                      0.243070  0.075664 -0.077461
# Num_opps                           -0.235744 -0.110735  0.174153
# Aphelion_dist                      -0.594912  0.197109  0.939460
# Peri                               -0.012193  0.002003  0.019704
# Orbital_period                     -0.538186 -0.033342  0.949559
# Perihelion_dist                    -0.767580 -0.528807  0.859020
# n                                   1.000000  0.247010 -0.732076
# e                                   0.247010  1.000000 -0.103563
# a                                  -0.732076 -0.103563  1.000000
# Semilatus_rectum                   -0.793860 -0.306206  0.956516
# Num_obs                            -0.116349 -0.208147  0.009769
# rms                                 0.115941  0.184009 -0.006957
# Node                                0.044909  0.005829 -0.041232
# Epoch                                    NaN       NaN       NaN
# G                                   0.013183 -0.007959 -0.011064
# M                                   0.004318 -0.012569 -0.003367
# Tp                                 -0.016690 -0.038778 -0.101815
# H                                   0.530207  0.222897 -0.457575
# i                                   0.021884  0.211395  0.094391
# U                                   0.386699  0.267977 -0.062722
# NEO_flag                                 NaN       NaN       NaN
# One_km_NEO_flag                          NaN       NaN       NaN
# PHA_flag                                 NaN       NaN       NaN
# Critical_list_numbered_object_flag       NaN       NaN       NaN
#
#                                     Semilatus_rectum  ...         G         M  \
# Synodic_period                             -0.089216  ...  0.000260  0.009851
# Num_opps                                    0.211162  ...  0.137773  0.010760
# Aphelion_dist                               0.806866  ... -0.011867 -0.008826
# Peri                                        0.017363  ...  0.006092 -0.010627
# Orbital_period                              0.852162  ... -0.007970 -0.007464
# Perihelion_dist                             0.958730  ... -0.007303  0.005567
# n                                          -0.793860  ...  0.013183  0.004318
# e                                          -0.306206  ... -0.007959 -0.012569
# a                                           0.956516  ... -0.011064 -0.003367
# Semilatus_rectum                            1.000000  ... -0.009127  0.000920
# Num_obs                                     0.062154  ...  0.160973  0.004433
# rms                                        -0.056011  ...  0.035296  0.019628
# Node                                       -0.042941  ...  0.004211  0.014040
# Epoch                                            NaN  ...       NaN       NaN
# G                                          -0.009127  ...  1.000000  0.017507
# M                                           0.000920  ...  0.017507  1.000000
# Tp                                         -0.064448  ...  0.010665  0.444570
# H                                          -0.516462  ... -0.093297 -0.011109
# i                                           0.039149  ...  0.006570  0.007062
# U                                          -0.145720  ... -0.005475  0.011781
# NEO_flag                                         NaN  ...       NaN       NaN
# One_km_NEO_flag                                  NaN  ...       NaN       NaN
# PHA_flag                                         NaN  ...       NaN       NaN
# Critical_list_numbered_object_flag               NaN  ...       NaN       NaN
#
#                                           Tp         H         i         U  \
# Synodic_period                      0.001276  0.065764  0.029664  0.422038
# Num_opps                            0.007462 -0.829405 -0.002395 -0.071393
# Aphelion_dist                      -0.141505 -0.346683  0.144103  0.017295
# Peri                               -0.012324 -0.020842 -0.007857 -0.014046
# Orbital_period                     -0.173878 -0.343485  0.094086  0.006758
# Perihelion_dist                    -0.018955 -0.517354 -0.001724 -0.167753
# n                                  -0.016690  0.530207  0.021884  0.386699
# e                                  -0.038778  0.222897  0.211395  0.267977
# a                                  -0.101815 -0.457575  0.094391 -0.062722
# Semilatus_rectum                   -0.064448 -0.516462  0.039149 -0.145720
# Num_obs                            -0.003189 -0.545615 -0.256363 -0.160904
# rms                                 0.018126  0.240807 -0.173948  0.164622
# Node                                0.020740  0.015404  0.015622  0.004098
# Epoch                                    NaN       NaN       NaN       NaN
# G                                   0.010665 -0.093297  0.006570 -0.005475
# M                                   0.444570 -0.011109  0.007062  0.011781
# Tp                                  1.000000 -0.004011  0.011432  0.003572
# H                                  -0.004011  1.000000 -0.225402  0.169788
# i                                   0.011432 -0.225402  1.000000  0.141336
# U                                   0.003572  0.169788  0.141336  1.000000
# NEO_flag                                 NaN       NaN       NaN       NaN
# One_km_NEO_flag                          NaN       NaN       NaN       NaN
# PHA_flag                                 NaN       NaN       NaN       NaN
# Critical_list_numbered_object_flag       NaN       NaN       NaN       NaN
#
#                                     NEO_flag  One_km_NEO_flag  PHA_flag  \
# Synodic_period                           NaN              NaN       NaN
# Num_opps                                 NaN              NaN       NaN
# Aphelion_dist                            NaN              NaN       NaN
# Peri                                     NaN              NaN       NaN
# Orbital_period                           NaN              NaN       NaN
# Perihelion_dist                          NaN              NaN       NaN
# n                                        NaN              NaN       NaN
# e                                        NaN              NaN       NaN
# a                                        NaN              NaN       NaN
# Semilatus_rectum                         NaN              NaN       NaN
# Num_obs                                  NaN              NaN       NaN
# rms                                      NaN              NaN       NaN
# Node                                     NaN              NaN       NaN
# Epoch                                    NaN              NaN       NaN
# G                                        NaN              NaN       NaN
# M                                        NaN              NaN       NaN
# Tp                                       NaN              NaN       NaN
# H                                        NaN              NaN       NaN
# i                                        NaN              NaN       NaN
# U                                        NaN              NaN       NaN
# NEO_flag                                 NaN              NaN       NaN
# One_km_NEO_flag                          NaN              NaN       NaN
# PHA_flag                                 NaN              NaN       NaN
# Critical_list_numbered_object_flag       NaN              NaN       NaN
#
#                                     Critical_list_numbered_object_flag
# Synodic_period                                                     NaN
# Num_opps                                                           NaN
# Aphelion_dist                                                      NaN
# Peri                                                               NaN
# Orbital_period                                                     NaN
# Perihelion_dist                                                    NaN
# n                                                                  NaN
# e                                                                  NaN
# a                                                                  NaN
# Semilatus_rectum                                                   NaN
# Num_obs                                                            NaN
# rms                                                                NaN
# Node                                                               NaN
# Epoch                                                              NaN
# G                                                                  NaN
# M                                                                  NaN
# Tp                                                                 NaN
# H                                                                  NaN
# i                                                                  NaN
# U                                                                  NaN
# NEO_flag                                                           NaN
# One_km_NEO_flag                                                    NaN
# PHA_flag                                                           NaN
# Critical_list_numbered_object_flag                                 NaN
#
# [24 rows x 24 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import style
style.use("seaborn-paper")


asteroid_df = pd.read_json('https://github.com/Marcel-Jan/Fun-with-Python/blob/master/mpcorb_10kasteroids.json?raw=true')

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(asteroid_df.a, asteroid_df.i, asteroid_df.e, color='k', marker='.')

ax.set_xlim(2, 3.5)
ax.set_ylim(0, 20)
ax.set_zlim(0, 0.5)

ax.set_xlabel('Semimajor axis')
ax.set_ylabel('Inclination')
ax.set_zlabel('Eccentricity')
ax.set_title('First 10,000 asteroids discovered')

plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# %%
sns.pairplot(asteroid_df, hue='a', height=2.5);

# %%
sns.jointplot(x="a", y="i", data=asteroid_df, kind='hex', xlim=5, ylim=40)

# %%
asteroid_df.i.describe()
# Out:
# count    10000.000000
# mean         7.892390
# std          6.337618
# min          0.042290
# 25%          3.219405
# 50%          6.019175
# 75%         10.921753
# max         68.005470
# Name: i, dtype: float64

# %%
sns.heatmap(asteroid_df.corr())

# %% [markdown]
# ## Dataset 2 - Planetas

# %%
planets = sns.load_dataset('planets')
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
with sns.axes_style('white'):
    g = sns.factorplot("year", data=planets, aspect=2,
                       kind="count", color='steelblue')
    g.set_xticklabels(step=5)
# Out:
# C:\Users\murip\anaconda3\envs\pyvizenv\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\murip\anaconda3\envs\pyvizenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - Veamos los métodos de discovery

# %%
with sns.axes_style('white'):
    g = sns.factorplot("year", data=planets, aspect=4.0, kind='count',
                       hue='method', order=range(2001, 2015))
    g.set_ylabels('Number of Planets Discovered')
# Out:
# C:\Users\murip\anaconda3\envs\pyvizenv\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\murip\anaconda3\envs\pyvizenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
planets.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
sns.jointplot('mass', 'orbital_period', planets, kind='reg', ylim=100000)
# Out:
# C:\Users\murip\anaconda3\envs\pyvizenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set_theme(style="whitegrid")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=planets,
    x="distance", y="orbital_period",
    hue="year", size="mass",
    palette=cmap, sizes=(10, 200),
)
g.set(xscale="log", yscale="log")
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True)

# %%
c = sns.JointGrid(data=planets, x="year", y="distance", marginal_ticks=True)

# Set a log scaling on the y axis
c.ax_joint.set(yscale="log")

# Create an inset legend for the histogram colorbar
cax = c.fig.add_axes([.15, .55, .02, .2])

# Add the joint and marginal histogram plots
c.plot_joint(
    sns.histplot, discrete=(True, False),
    cmap="light:#03012d", pmax=.8, cbar=True, cbar_ax=cax
)

# %%
sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

# Plot the orbital period with horizontal boxes
sns.boxplot(x="distance", y="method", data=planets,
            whis=[0, 100], width=.6, palette="vlag")

# Add in points to show each observation
sns.stripplot(x="distance", y="method", data=planets,
              size=4, color=".3", linewidth=0)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)
# Out:
# C:\Users\murip\AppData\Roaming\Python\Python37\site-packages\numpy\core\_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
sns.pairplot(planets)
